# %% [markdown]
# #Data Engineering Pipeline – Bronze Layer (Landing, Backup & Delta Initialization)

# %%
#Load the Airbnb dataset from aws s3 buckek into databricks Spark DataFrame

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3://airbnb-dataset012/listings.csv")

display(df)

# %%
#Save RAW Copy of CSV in Databricks bronze Layer

df.write.format("csv") \
    .mode("overwrite") \
    .option("header", "true") \
    .save("/Volumes/airbnb/bronze/listings")

# %%
# read raw csv file data backup from bronze layer

df = spark.read.format("csv") \
    .option("header", "true") \
    .load("/Volumes/airbnb/bronze/listings")
df.display()

# %%
# saving the bronze layer csv file into delta format

raw_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("airbnb.bronze.listings_table")
